# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
f=pd.read_csv('heart-disease.csv')

# %%
df=pd.DataFrame(f)
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
ff=pd.read_csv('diabetes_prediction_dataset.csv')

# %%
dff=pd.DataFrame(ff)
dff
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %%
dff['gender'].unique()
# Out:
# array(['Female', 'Male', 'Other'], dtype=object)

# %%
dff['smoking_history'].unique()
# Out:
# array(['never', 'No Info', 'current', 'former', 'ever', 'not current'],
#       dtype=object)

# %%
dff['gender'] = dff['gender'].replace({'Other':2,'Male': 1, 'Female': 0})

# %%
dff['smoking_history'] = dff['smoking_history'].replace({'never':0,'No Info': 1, 'current': 2,'former':3,'ever':4,'not current':5})

# %%
dff
# Out:
#        gender   age  hypertension  heart_disease  smoking_history    bmi  \
# 0           0  80.0             0              1                0  25.19
# 1           0  54.0             0              0                1  27.32
# 2           1  28.0             0              0                0  27.32
# 3           0  36.0             0              0                2  23.45
# 4           1  76.0             1              1                2  20.14
# ...       ...   ...           ...            ...              ...    ...
# 99995       0  80.0             0              0                1  27.32
# 99996       0   2.0             0              0                1  17.37
# 99997       1  66.0             0              0                3  27.83
# 99998       0  24.0             0              0                0  35.42
# 99999       0  57.0             0              0                2  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# ...

# %%
def distance(p1,p2):
    return np.sqrt(np.sum((p1-p2)**2))
