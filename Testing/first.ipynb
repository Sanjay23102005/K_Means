# %%
import numpy as np
import pandas as pd
from Cluster import Cluster
from kmean import k_means,result

# %%
f=pd.read_csv('diabetes_prediction_dataset.csv')
df=pd.DataFrame(f)
df
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %%
df['gender'] = df['gender'].replace({'Other':2,'Male': 1, 'Female': 0})
df['smoking_history'] = df['smoking_history'].replace({'never':0,'No Info': 1, 'current': 5,'former':2,'ever':4,'not current':3})

# %%
features=df.values
df[df['diabetes']==1]
# Out:
#        gender   age  hypertension  heart_disease  smoking_history    bmi  \
# 6           0  44.0             0              0                0  19.31
# 26          1  67.0             0              1                3  27.32
# 38          1  50.0             1              0                5  27.32
# 40          1  73.0             0              0                2  25.91
# 53          0  53.0             0              0                2  27.32
# ...       ...   ...           ...            ...              ...    ...
# 99935       0  65.0             1              1                0  33.55
# 99938       1  55.0             0              1                2  30.42
# 99957       0  61.0             0              0                1  34.45
# 99962       0  58.0             1              0                0  38.31
# 99979       0  61.0             0              0                5  30.11
#
#        HbA1c_level  blood_glucose_level  diabetes
# ...

# %%
k=2
clusters=[Cluster(features[53]),Cluster(features[1])]

# %%
k_means(clusters,features)
# Out:
# Epoch 1

# %%
total_diabetes_patients=8500
result(clusters,total_diabetes_patients)
# Out:
# Cluster 1 Centroid: [  0.    53.     0.     0.     2.    27.32   7.   159.     1.  ]
# Cluster 1 Diabetes Patients: 8500
# Percentage of Total Diabetes Patients in Cluster 1: 100.00%
# Cluster 2 Centroid: [ 0.   54.    0.    0.    1.   27.32  6.6  80.    0.  ]
# Cluster 2 Diabetes Patients: 0
# Percentage of Total Diabetes Patients in Cluster 2: 0.00%
